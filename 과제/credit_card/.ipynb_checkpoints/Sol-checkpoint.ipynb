# %% [markdown]
# # credit-card-approval-prediction 문제
#
# - 제작자: 서동옥
# - 도움을 주신분: 신동원

# %% [markdown]
# ### 문제1: application_recode.csv와 credit_record.csv를 appli과 cred에 데이터프레임으로 할당하세요

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
appli = pd.read_csv('./application_record.csv')
cred = pd.read_csv('./credit_record.csv')

# %% [markdown]
# ### 문제2: appli과 cred의 행과 열의 길이를 출력하세요

# %%
print("appli.shape",appli.shape)
print("cred.shape",cred.shape)
# Out:
# appli.shape (438557, 18)
# cred.shape (1048575, 3)

# %% [markdown]
# ### 문제3: appli과 cred를 id를 기준으로 합쳐서 df라는 하나의 데이터 프레임으로 만드세요
# 0: 29
# 1: 59
# 2: 89
# 3: 119
# 4: 149
# 5: 200
# c: 0
# x: 0

# %%
df = pd.merge(appli,cred,on="ID",how="left")
df
# Out:
#               ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0        5008804           M            Y               Y             0
# 1        5008804           M            Y               Y             0
# 2        5008804           M            Y               Y             0
# 3        5008804           M            Y               Y             0
# 4        5008804           M            Y               Y             0
# ...          ...         ...          ...             ...           ...
# 1179810  6840104           M            N               Y             0
# 1179811  6840222           F            N               N             0
# 1179812  6841878           F            N               N             0
# 1179813  6842765           F            N               Y             0
# 1179814  6842885           F            N               Y             0
#
#          AMT_INCOME_TOTAL      NAME_INCOME_TYPE  \
# 0                427500.0               Working
# ...

# %% [markdown]
# ### 문제4: df의 결측치를 확인하고 있다면 해당 열(colume)을 삭제하세요

# %%
df.isna().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        362928
# CNT_FAM_MEMBERS             0
# MONTHS_BALANCE         402100
# STATUS                 402100
# dtype: int64

# %%
# del df["OCCUPATION_TYPE"]
# del df["MONTHS_BALANCE"]
# del df["STATUS"]

# %% [markdown]
# ### 문제5: 각 열의 고유한 데이터의 수를 출력하세요.

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n\n")
# Out:
# ID
# 5117576    61
# 5089140    61
# 5041979    61
# 5139545    61
# 5105840    61
#            ..
# 5797366     1
# 5797365     1
# 5797364     1
# 5797362     1
# 6842885     1
# Name: count, Length: 438510, dtype: int64
#
#
#
# CODE_GENDER
# F    788861
# M    390954
# Name: count, dtype: int64
#
#
#
# FLAG_OWN_CAR
# N    726200
# Y    453615
# Name: count, dtype: int64
#
#
#
# FLAG_OWN_REALTY
# Y    792516
# N    387299
# Name: count, dtype: int64
#
#
#
# CNT_CHILDREN
# 0     819509
# 1     236673
# 2     107027
# 3      14339
# 4       1647
# 5        437
# 14       111
# 7         53
# 19         6
# 9          5
# 12         4
# 6          4
# Name: count, dtype: int64
#
#
#
# AMT_INCOME_TOTAL
# 135000.0    132787
# 180000.0    103394
# 157500.0     99365
# 112500.0     95645
# 225000.0     92603
#              ...
# 45450.0          1
# 187497.0         1
# 116550.0         1
# 128646.0         1
# 132075.0         1
# Name: count, Length: 866, dtype: int64
#
#
#
# ...

# %% [markdown]
# ### 문제6:ID가 중복 데이터의 수를 확인하고 상위 10개와 하위 10개를 각각 출력하세요

# %%
print("duplicate:",df.duplicated().sum())
print("head",df.head(10))
print("tail",df.tail(10))
# Out:
# duplicate: 741258
# head         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
# 5  5008804           M            Y               Y             0
# 6  5008804           M            Y               Y             0
# 7  5008804           M            Y               Y             0
# 8  5008804           M            Y               Y             0
# 9  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# ...

# %% [markdown]
# ### 문제7: 컬럼을 다음과 같이 수정하세요
#
#     'CODE_GENDER': 'gender',
#     'FLAG_OWN_CAR': 'own_car',
#     'FLAG_OWN_REALTY': 'own_property',
#     'CNT_CHILDREN': 'children',
#     'AMT_INCOME_TOTAL': 'income',
#     'NAME_INCOME_TYPE': 'income_type',
#     'NAME_EDUCATION_TYPE': 'education',
#     'NAME_FAMILY_STATUS': 'family_status',
#     'NAME_HOUSING_TYPE': 'housing_type',
#     'FLAG_MOBIL': 'mobile',
#     'FLAG_WORK_PHONE': 'work_phone',
#     'FLAG_PHONE': 'phone',
#     'FLAG_EMAIL': 'email',
#     'CNT_FAM_MEMBERS': 'family_members',
#     'MONTHS_BALANCE': 'months_balance',
#     'STATUS' : 'status',
#     'DAYS_BIRTH' : 'age_in_days',
#     'DAYS_EMPLOYED' : 'employment_in_days'

# %%
df.rename(columns={    
    'CODE_GENDER': 'gender',
    'FLAG_OWN_CAR': 'own_car',
    'FLAG_OWN_REALTY': 'own_property',
    'CNT_CHILDREN': 'children',
    'AMT_INCOME_TOTAL': 'income',
    'NAME_INCOME_TYPE': 'income_type',
    'NAME_EDUCATION_TYPE': 'education',
    'NAME_FAMILY_STATUS': 'family_status',
    'NAME_HOUSING_TYPE': 'housing_type',
    'FLAG_MOBIL': 'mobile',
    'FLAG_WORK_PHONE': 'work_phone',
    'FLAG_PHONE': 'phone',
    'FLAG_EMAIL': 'email',
    'CNT_FAM_MEMBERS': 'family_members',
    'MONTHS_BALANCE': 'months_balance',
    'STATUS' : 'status',
    'DAYS_BIRTH' : 'age_in_days',
    'DAYS_EMPLOYED' : 'employment_in_days'
})

# %% [markdown]
# ### 문제8: 컬럼 gender가 female 경우 F, male일 경우 M으로 수정하세요

# %% [markdown]
# ### 문제9: gender가 M일때 own_car가 yes인 경우의 합을 출력하세요

# %% [markdown]
# ### 문제10:housing_type의 그룹별로 income을 100000, 300000를 기준으로 low, medium, hihg로 구분하여 3개의 막대로 그래프로 나타내세요

# %% [markdown]
# ### 문제11: 위 문제에서 분류한 3개의 income그룹의 아이디에 따른 연체기간의 합을 막대 그래프로 나타내세요
